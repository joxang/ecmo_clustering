# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
normclust = pd.read_csv('../normalized_clustered.csv', index_col = 0)

# %%
normclust.columns
# Out:
# Index(['age', 'bmi', 'ed_v', 'v_vv', 'sofa', 'pfr', 'pco2', 'pplat', 'lymph',
#        'nlrat', 'pct', 'ferritin', 'crp', 'fib', 'ddim', 'cluster'],
#       dtype='object')

# %%
features = ['age', 'bmi', 'ed_v', 'v_vv', 'sofa', 'pfr', 'pco2', 'pplat', 'lymph',
       'nlrat', 'pct', 'ferritin', 'crp', 'fib', 'ddim']

x = normclust.loc[:, features].values
y = normclust.loc[:,['cluster']].values

# %%
pca = PCA(n_components=2)

principalComponents = pca.fit_transform(x)

# %%
pcadf = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2'])
pcaclus = pd.concat([pcadf, normclust[['cluster']]], axis = 1)

# %%
# Create a DF of feature significancs

components = pd.DataFrame(pca.components_, columns=features, index=['PC1', 'PC2'])

# %%
components
# Out:
#           age       bmi      ed_v      v_vv      sofa       pfr      pco2  \
# PC1  0.247725 -0.055894 -0.073255  0.130543  0.445569 -0.175508  0.034277
# PC2  0.148001  0.145052  0.421740 -0.650058  0.026534 -0.091460  0.051647
#
#         pplat     lymph     nlrat       pct  ferritin       crp       fib  \
# PC1  0.098418 -0.008681  0.003483  0.468862  0.146877  0.391609  0.246957
# PC2 -0.051589 -0.339887  0.258898  0.098470  0.108427 -0.027775 -0.320599
#
#          ddim
# PC1  0.465906
# PC2  0.186166

# %%
sns.set_style("ticks")

fig = plt.figure(figsize=(12,12))
fig.tight_layout()
ax = fig.add_subplot()

x0 = pcaclus[pcaclus['cluster'] == 0]['PC1']
y0 = pcaclus[pcaclus['cluster'] == 0]['PC2']
x1 = pcaclus[pcaclus['cluster'] == 1]['PC1']
y1 = pcaclus[pcaclus['cluster'] == 1]['PC2']
x2 = pcaclus[pcaclus['cluster'] == 2]['PC1']
y2 = pcaclus[pcaclus['cluster'] == 2]['PC2']
clus = pcaclus['cluster']

c0 = plt.scatter(x0, y0, s=150, marker="X", label='Cluster 0', c='k')
c1 = plt.scatter(x1, y1, s=120, marker="D", label='Cluster 1', c='k')
c2 = plt.scatter(x2, y2, s=150, marker="o", label='Cluster 2', c='k')

ax.legend(loc='upper left')

ax.set_title('Cluster Membership Represented \n Following Dimensionality Reduction With PCA', fontsize=30, pad=50)
#ax.set_xlabel('Princal Component 1')
#ax.set_ylabel('Princal Component 2')

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.set_ylim(-1,1)
ax.set_xlim(-1,1)

plt.show()

# %%
# Plot with liens representing the contribution of each feature to the principal components


sns.set_style("ticks")

fig = plt.figure(figsize=(12,12))
fig.tight_layout()
ax = fig.add_subplot()

x0 = pcaclus[pcaclus['cluster'] == 0]['PC1']
y0 = pcaclus[pcaclus['cluster'] == 0]['PC2']
x1 = pcaclus[pcaclus['cluster'] == 1]['PC1']
y1 = pcaclus[pcaclus['cluster'] == 1]['PC2']
x2 = pcaclus[pcaclus['cluster'] == 2]['PC1']
y2 = pcaclus[pcaclus['cluster'] == 2]['PC2']
clus = pcaclus['cluster']

for i in components.columns:
        plt.arrow(0, 0, components.loc['PC1', i], components.loc['PC2',i],color = 'r',alpha = 0.5)
        plt.text(components.loc['PC1',i]* 1.15, components.loc['PC2',i] * 1.15, i, color = 'g', ha = 'center', va = 'center')

c0 = plt.scatter(x0, y0, s=150, marker="X", label='Cluster 0', c='k')
c1 = plt.scatter(x1, y1, s=120, marker="D", label='Cluster 1', c='k')
c2 = plt.scatter(x2, y2, s=150, marker="o", label='Cluster 2', c='k')



ax.legend(loc='upper left')

ax.set_title('Cluster Membership Represented \n Following Dimensionality Reduction With PCA', fontsize=30, pad=50)
#ax.set_xlabel('Princal Component 1')
#ax.set_ylabel('Princal Component 2')

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.set_ylim(-1,1)
ax.set_xlim(-1,1)

plt.show()
